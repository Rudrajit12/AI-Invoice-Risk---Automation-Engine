# %% [markdown]
# # Stage 2 — Synthetic AP dataset
#
# This notebook is a lightweight, reproducible entry point. The generator and validator live in `src/` so they can also run in CI or from the command line.

# %%
from pathlib import Path
import subprocess

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
subprocess.run(['python', 'src/generate_synthetic_data.py'], cwd=root, check=True)
subprocess.run(['python', 'src/validate_data.py'], cwd=root, check=True)

# %%
import json

manifest = json.loads((root / 'data/synthetic/manifest.json').read_text())
manifest
